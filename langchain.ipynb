# %%
# !pip install langchain langchain-community langchain-core langchain-openai openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 2.7 MB/s eta 0:00:00
# ...

# %%
from langchain.chat_models import init_chat_model

# Example: initializing a chat model in LangChain
# NOTE: Running this requires setting an OPENAI_API_KEY environment variable

# model = init_chat_model("gpt-5-nano")

print("Example code shown. Requires OpenAI API key to execute.")
# Out:
# Example code shown. Requires OpenAI API key to execute.

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import PromptTemplate

# Example chain using prompt + model
# NOTE: Requires OpenAI API key to execute fully

prompt = PromptTemplate.from_template(
    "Explain the role of {topic} in LangChain"
)

# model = init_chat_model("gpt-5-nano")
# chain = prompt | model
# result = chain.invoke({"topic": "memory"})
# print(result.text())

print("Chain example prepared. Requires OpenAI API key to execute.")
# Out:
# Chain example prepared. Requires OpenAI API key to execute.

# %%
from langchain.agents import create_agent

def calculator(expression: str):
    return str(eval(expression))

# Example agent setup
# NOTE: Requires OpenAI API key to execute fully

# agent = create_agent(
#     model="openai:gpt-4.1-mini",
#     tools=[calculator],
#     system_prompt="You are a helpful assistant"
# )

# result = agent.invoke(
#     {"messages":[{"role":"user","content":"What is 25 * 4?"}]}
# )
# print(result)

print("Agent example prepared. Requires OpenAI API key to execute.")
# Out:
# Agent example prepared. Requires OpenAI API key to execute.
